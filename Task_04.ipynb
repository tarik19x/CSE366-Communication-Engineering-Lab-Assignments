# %% [markdown]
# <a href="https://colab.research.google.com/github/tarik19x/CSE366-Communication-Engineering-Lab-Assignments/blob/main/Task_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #$$\color{black}{\textbf{Reg.No: 2017331019} }$$

# %% [markdown]
# <br>
#
# # **A program to simulate the analog-analog conversion techniques(Modulation techniques - FM, AM, PM)}**
# <br>
# <br>

# %% [markdown]
# # **Frequency Modulation**
#
# In FM transmission, the frequency of the carrier signal is modulated to follow the changing voltage level (amplitude) of the modulating signal. The peak amplitude and phase of the carrier signal remain constant, but as the amplitude of the information signal changes, the frequency of the carrier changes correspondingly.FM is normally implemented by using a voltage-controlled
# oscillator as with FSK. The frequency of the oscillator changes according to the input voltage which is the amplitude of the modulating signal.The total bandwidth required for FM can be determined from the bandwidth of the audio signal:$$B_fm = 2(1 * \beta)B $$.

# %%
# Regi.No: 2017331019
import numpy as np
import matplotlib.pyplot as plt

modulator_frequency = 4.0
carrier_frequency = 40.0
modulation_index = 1.0

time = np.arange(44100.0) / 44100.0
modulator = np.sin(2.0 * np.pi * modulator_frequency * time) * modulation_index
carrier = np.sin(2.0 * np.pi * carrier_frequency * time)
product = np.zeros_like(modulator)

for i, t in enumerate(time):
    product[i] = np.sin(2. * np.pi * (carrier_frequency * t + modulator[i]))

# Modulator signal
plt.figure(figsize=(12,2.5))
plt.title('Frequency Modulation')
plt.plot(modulator)
plt.ylabel('Amplitude')
plt.xlabel('Modulator signal')
plt.show()


# Carrier signal
plt.figure(figsize=(12,2.5))
plt.plot(carrier)
plt.ylabel('Amplitude')
plt.xlabel('Carrier signal')
plt.show()

# Carrier signal
plt.figure(figsize=(12,2.5))
plt.plot(product)
plt.ylabel('Amplitude')
plt.xlabel('Output signal')
plt.show()

# %% [markdown]
# # **Amplitude Modulation**
#
# In AM transmission, the carrier signal is modulated so that its amplitude varies with the changing amplitudes of the modulating signal. The frequency and phase of the carrier remain the same; only the amplitude changes to follow variations in the information.

# %%
A_c = 100.0
f_c = 120.0
A_m = 140.0
f_m = 200.0
modulation_index =2.0

t = np.linspace(0, 1, 1000)

#Carrier wave
carrier = A_c*np.cos(2*np.pi*f_c*t)

#Modulating wave
modulator = A_m*np.cos(2*np.pi*f_m*t)

#Modulated wave 
product = A_c*(1+modulation_index*np.cos(2*np.pi*f_m*t))*np.cos(2*np.pi*f_c*t)

plt.subplot(3,1,1)
plt.title('Amplitude Modulation')
plt.plot(modulator,'g')
plt.ylabel('Amplitude')
plt.xlabel('Message signal')

plt.subplot(3,1,2)
plt.plot(carrier, 'r')
plt.ylabel('Amplitude')
plt.xlabel('Carrier signal')

plt.subplot(3,1,3)
plt.plot(product, color="purple")
plt.ylabel('Amplitude')
plt.xlabel('AM signal')

plt.subplots_adjust(hspace=1)
plt.rc('font', size=15)
fig = plt.gcf()
fig.set_size_inches(16, 12)

# %% [markdown]
# #**Phase Modulation**
#
# In PM transmission, the phase of the carrier signal is modulated to follow the changing voltage level (amplitude) of the modulating signal. The peak amplitude and frequency.of the carrier signal remain constant, but as the amplitude of the information signal changes, the phase of the carrier changes correspondingly.

# %%
import numpy as np
from math import pi
from numpy import cos, absolute
import matplotlib.pyplot as plt
from numpy.fft import fft, fftshift

# %%
# Phase Modulation

Sampling_Frequency = 8000
Carrier_Frequency =100
Carrier_Amplitude =1
Message_Frequency =5
Message_Amplitude =1
Modulation_Coefficient =20

# %%
# Time Domain Analysis

time = np.arange(0,1,1/Sampling_Frequency)
Message_Signal = Message_Amplitude*cos(2*pi*Message_Frequency*time)
Carrier_Signal = Carrier_Amplitude*cos(2*pi*Carrier_Frequency*time)

# %%
PM_signal = []
for (ti, m) in zip(time, Message_Signal):
    PM_signal.append(Carrier_Amplitude*cos(2*pi*Carrier_Frequency*ti + Modulation_Coefficient*m))

# %%
# Ploting the Message Signal
plt.figure(figsize=(13,2.5))
plt.plot(time,Message_Signal)
plt.title("Message Signal")
plt.xlabel("Time")
plt.ylabel("Amplitude")
plt.show()

# Ploting the Carrier Signal
plt.figure(figsize=(13,2.5))
plt.plot(time,Carrier_Signal)
plt.title("Carrier Signal")
plt.xlabel("Time")
plt.ylabel("Amplitude")
plt.show()

# Ploting the PM Signal
plt.figure(figsize=(13,2.5))
plt.plot(time,PM_signal,time,Message_Signal)
plt.title("PM Signal")
plt.xlabel("Time")
plt.ylabel("Amplitude")
plt.show()
